# %%
import pandas as pd

# %%
population2020_2029 = pd.read_csv('./population_data/population-2020-2029.csv')
population2020_2029.head()
# Out:
#   LocID             Location  Time AgeGrp AgeGrpStart AgeGrpSpan   PopMale  \
# 0     4          Afghanistan  2020    0-4           0          5  2907.406
# 1     8              Albania  2020    0-4           0          5    86.564
# 2    12              Algeria  2020    0-4           0          5  2574.062
# 3    24               Angola  2020    0-4           0          5  2923.514
# 4    28  Antigua and Barbuda  2020    0-4           0          5      3.73
#
#   PopFemale  PopTotal
# 0  2765.103  5672.509
# 1    79.714   166.278
# 2  2467.456  5041.518
# 3   2871.49  5795.004
# 4     3.625     7.355
