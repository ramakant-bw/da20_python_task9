# %% [markdown]
# ### Importing pandas

# %%
import pandas as pd

# %%
population2030_2040 = pd.read_excel('./population_data/population-2030-2040.xlsx')
population2030_2040.head()
# Out:
#    LocID             Location    Time AgeGrp  AgeGrpStart  AgeGrpSpan  \
# 0    4.0          Afghanistan  2030.0    0-4          0.0         5.0
# 1    8.0              Albania  2030.0    0-4          0.0         5.0
# 2   12.0              Algeria  2030.0    0-4          0.0         5.0
# 3   24.0               Angola  2030.0    0-4          0.0         5.0
# 4   28.0  Antigua and Barbuda  2030.0    0-4          0.0         5.0
#
#     PopMale  PopFemale  PopTotal
# 0  3020.571   2871.955  5892.526
# 1    68.824     63.581   132.405
# 2  2116.681   2026.749  4143.430
# 3  3714.206   3649.187  7363.393
# 4     3.452      3.354     6.806

# %%
df_population2030_2040 = population2030_2040

# %%
df_population2030_2040.rename(columns={'Time': 'Year'}, inplace=True)
df_population2030_2040.head()
# Out:
#    LocID             Location    Year AgeGrp  AgeGrpStart  AgeGrpSpan  \
# 0    4.0          Afghanistan  2030.0    0-4          0.0         5.0
# 1    8.0              Albania  2030.0    0-4          0.0         5.0
# 2   12.0              Algeria  2030.0    0-4          0.0         5.0
# 3   24.0               Angola  2030.0    0-4          0.0         5.0
# 4   28.0  Antigua and Barbuda  2030.0    0-4          0.0         5.0
#
#     PopMale  PopFemale  PopTotal
# 0  3020.571   2871.955  5892.526
# 1    68.824     63.581   132.405
# 2  2116.681   2026.749  4143.430
# 3  3714.206   3649.187  7363.393
# 4     3.452      3.354     6.806

# %%
df_population2030_2040.describe()
# Out:
#               LocID          Year   AgeGrpStart    AgeGrpSpan     PopFemale  \
# count  45969.000000  45969.000000  45969.000000  45969.000000  45969.000000
# mean     443.718593   2035.000000     50.000000      4.714286   1047.230715
# std      275.311449      3.162312     30.276833      1.277767   4263.800121
# min        4.000000   2030.000000      0.000000     -1.000000      0.000000
# 25%      218.000000   2032.000000     25.000000      5.000000     15.434000
# 50%      428.000000   2035.000000     50.000000      5.000000    135.889000
# 75%      662.000000   2038.000000     75.000000      5.000000    630.559000
# max     1835.000000   2040.000000    100.000000      5.000000  61689.278000
#
#             PopTotal
# count   45969.000000
# mean     2108.812505
# std      8805.202840
# min         0.000000
# 25%        28.232000
# 50%       263.369000
# 75%      1228.273000
# max    127239.526000

# %%
df_population2030_2040.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45976 entries, 0 to 45975
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LocID        45969 non-null  float64
#  1   Location     45969 non-null  object
#  2   Year         45969 non-null  float64
#  3   AgeGrp       45969 non-null  object
#  4   AgeGrpStart  45969 non-null  float64
#  5   AgeGrpSpan   45969 non-null  float64
#  6   PopMale      45969 non-null  object
#  7   PopFemale    45969 non-null  float64
#  8   PopTotal     45969 non-null  float64
# dtypes: float64(6), object(3)
# memory usage: 3.2+ MB

# %% [markdown]
# ### Correcting values by Replacing values

# %%
df_population2030_2040['AgeGrp'] = df_population2030_2040['AgeGrp'].replace({'100+':'100-104'})
df_population2030_2040
# Out:
#        LocID             Location    Year   AgeGrp  AgeGrpStart  AgeGrpSpan  \
# 0        4.0          Afghanistan  2030.0      0-4          0.0         5.0
# 1        8.0              Albania  2030.0      0-4          0.0         5.0
# 2       12.0              Algeria  2030.0      0-4          0.0         5.0
# 3       24.0               Angola  2030.0      0-4          0.0         5.0
# 4       28.0  Antigua and Barbuda  2030.0      0-4          0.0         5.0
# ...      ...                  ...     ...      ...          ...         ...
# 45971  308.0              Grenada  2040.0  100-104        100.0        -1.0
# 45972  426.0              Lesotho  2040.0  100-104        100.0        -1.0
# 45973  516.0              Namibia  2040.0  100-104        100.0        -1.0
# 45974  690.0           Seychelles  2040.0  100-104        100.0        -1.0
# 45975  776.0                Tonga  2040.0  100-104        100.0        -1.0
#
#         PopMale  PopFemale  PopTotal
# ...

# %% [markdown]
# ### Removing unwanted column 'AgeGrpSpan'

# %%
df_population2030_2040.drop(columns=['AgeGrpSpan'], inplace=True)
df_population2030_2040
# Out:
#        LocID             Location    Year   AgeGrp  AgeGrpStart   PopMale  \
# 0        4.0          Afghanistan  2030.0      0-4          0.0  3020.571
# 1        8.0              Albania  2030.0      0-4          0.0    68.824
# 2       12.0              Algeria  2030.0      0-4          0.0  2116.681
# 3       24.0               Angola  2030.0      0-4          0.0  3714.206
# 4       28.0  Antigua and Barbuda  2030.0      0-4          0.0     3.452
# ...      ...                  ...     ...      ...          ...       ...
# 45971  308.0              Grenada  2040.0  100-104        100.0     0.001
# 45972  426.0              Lesotho  2040.0  100-104        100.0     0.001
# 45973  516.0              Namibia  2040.0  100-104        100.0     0.001
# 45974  690.0           Seychelles  2040.0  100-104        100.0     0.001
# 45975  776.0                Tonga  2040.0  100-104        100.0     0.001
#
#        PopFemale  PopTotal
# 0       2871.955  5892.526
# ...

# %% [markdown]
# ### Correcting values by Replacing values

# %%
df_population2030_2040['PopMale'] = df_population2030_2040['PopMale'].replace({'ERROR_6.246':'8976.267'})
df_population2030_2040
# Out:
#        LocID             Location    Year   AgeGrp  AgeGrpStart   PopMale  \
# 0        4.0          Afghanistan  2030.0      0-4          0.0  3020.571
# 1        8.0              Albania  2030.0      0-4          0.0    68.824
# 2       12.0              Algeria  2030.0      0-4          0.0  2116.681
# 3       24.0               Angola  2030.0      0-4          0.0  3714.206
# 4       28.0  Antigua and Barbuda  2030.0      0-4          0.0     3.452
# ...      ...                  ...     ...      ...          ...       ...
# 45971  308.0              Grenada  2040.0  100-104        100.0     0.001
# 45972  426.0              Lesotho  2040.0  100-104        100.0     0.001
# 45973  516.0              Namibia  2040.0  100-104        100.0     0.001
# 45974  690.0           Seychelles  2040.0  100-104        100.0     0.001
# 45975  776.0                Tonga  2040.0  100-104        100.0     0.001
#
#        PopFemale  PopTotal
# 0       2871.955  5892.526
# ...

# %%
df_population2030_2040.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45976 entries, 0 to 45975
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LocID        45969 non-null  float64
#  1   Location     45969 non-null  object
#  2   Year         45969 non-null  float64
#  3   AgeGrp       45969 non-null  object
#  4   AgeGrpStart  45969 non-null  float64
#  5   PopMale      45969 non-null  object
#  6   PopFemale    45969 non-null  float64
#  7   PopTotal     45969 non-null  float64
# dtypes: float64(5), object(3)
# memory usage: 2.8+ MB

# %%
df_population2030_2040.describe()
# Out:
#               LocID          Year   AgeGrpStart     PopFemale       PopTotal
# count  45969.000000  45969.000000  45969.000000  45969.000000   45969.000000
# mean     443.718593   2035.000000     50.000000   1047.230715    2108.812505
# std      275.311449      3.162312     30.276833   4263.800121    8805.202840
# min        4.000000   2030.000000      0.000000      0.000000       0.000000
# 25%      218.000000   2032.000000     25.000000     15.434000      28.232000
# 50%      428.000000   2035.000000     50.000000    135.889000     263.369000
# 75%      662.000000   2038.000000     75.000000    630.559000    1228.273000
# max     1835.000000   2040.000000    100.000000  61689.278000  127239.526000
